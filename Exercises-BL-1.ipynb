# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.read_csv('data/titles.csv')
titles.head()
# Out:
#              title  year
# 0   Orlando Vargas  2005
# 1         Niu-Peng  1989
# 2    Anandabhadram  2005
# 3   Mahendra Varma  1993
# 4  Beomdiga shidae  1970

# %%
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %% [markdown]
# There are multiple ways to do that

# %%
titles.shape[0]
# Out:
# 214591

# %%
titles.size//len(titles.columns)
# Out:
# 214591

# %%
titles.index.size
# Out:
# 214591

# %%
len(titles)
# Out:
# 214591

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.sort_values(['year'], ascending=True).iloc[:2]
# Out:
#                                                    title  year
# 90767                                         Miss Jerry  1894
# 10994  Reproduction of the Corbett and Fitzsimmons Fight  1897

# %%
titles.sort_values(['year'], ascending=True).head(2)
# Out:
#                                                    title  year
# 90767                                         Miss Jerry  1894
# 10994  Reproduction of the Corbett and Fitzsimmons Fight  1897

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
ham = titles[titles.title == 'Hamlet']
len(ham)
ham.shape[0]
# Out:
# 19
# 19

# %%
haml = titles.loc[titles.title == 'Hamlet']
len(haml)
haml.shape[0]
# Out:
# 19
# 19

# %%
# I forgot about this method this time

# What does the '==' return? A big list of trues or falses. Basically 0s and 1s.

# So we only need to do this

sum(titles.title == 'Hamlet')
# Out:
# 19

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
# %%time

sum(titles.title == 'North by Northwest')
# Out:
# Wall time: 25 ms
# 1

# %%
# %%time 
titles[titles.title == 'North by Northwest'].shape[0]
# Out:
# Wall time: 11 ms
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
ham.sort_values(['year']).head()
# Out:
#          title  year
# 100923  Hamlet  1910
# 179411  Hamlet  1911
# 85485   Hamlet  1913
# 139892  Hamlet  1921
# 156599  Hamlet  1948

# %%
ham.sort_values(['year']).head(1).year
# Out:
# 100923    1910
# Name: year, dtype: int64

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles.title == 'Treasure Island'].sort_values('year')
# Out:
#                   title  year
# 48904   Treasure Island  1918
# 108475  Treasure Island  1920
# 89471   Treasure Island  1934
# 52435   Treasure Island  1950
# 118309  Treasure Island  1972
# 144139  Treasure Island  1973
# 191845  Treasure Island  1985
# 50325   Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
titles[titles.year == 1950]
# Out:
#                         title  year
# 71         La negra Angustias  1950
# 155        Shri Krishan Leela  1950
# 185        Hochzeit mit Erika  1950
# 551         Rio Grande Patrol  1950
# 709                 Dominique  1950
# ...                       ...   ...
# 214230      Please Believe Me  1950
# 214295       Ela sto theio...  1950
# 214324               Do Ansoo  1950
# 214347  Die fidele Tankstelle  1950
# 214438       Kami ang sugatan  1950
#
# [1036 rows x 2 columns]

# %%
titles[titles.year == 1950].shape
len(titles[titles.year == 1950])
# Out:
# (1036, 2)
# 1036

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
titles[titles.year == 1960].shape
len(titles[titles.year == 1960])
# Out:
# (1461, 2)
# 1461

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
titles[titles.year//10 == 195].shape
len(titles[titles.year//10 == 195])
# Out:
# (12110, 2)
# 12110

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles[titles.title == 'Batman']
# Out:
#         title  year
# 16656  Batman  1989
# 56309  Batman  1943

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast[cast.title == 'Inception']
# Out:
#              title  year                  name     type  \
# 85565    Inception  2010  Michael (III) August    actor
# 130207   Inception  2010          Peter Basham    actor
# 161273   Inception  2010          Tom Berenger    actor
# 173593   Inception  2010              Ken Bhan    actor
# 228660   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 2972865  Inception  2010            Ellen Page  actress
# 3021835  Inception  2010        Nicole Pulliam  actress
# 3045839  Inception  2010    Lisa (II) Reynolds  actress
# 3051953  Inception  2010         Talulah Riley  actress
# 3265183  Inception  2010        Shannon Welles  actress
#
#                      character     n
# 85565            LAX Passenger   NaN
# 130207   Fischer's Jet Captain  44.0
# 161273                Browning   8.0
# 173593        Mombasan Gambler   NaN
# 228660          Bridge Sub Con  29.0
# ...                        ...   ...
# ...

# %%
cast[cast.title == 'Inception'].character.drop_duplicates().size
# Out:
# 51

# %%
inc = cast[cast.title == 'Inception']#.character
inc[inc.duplicated(['character'], keep = False)]
inc[inc.duplicated(['character'], keep = 'first')].shape
# Out:
#              title  year                  name     type        character     n
# 85565    Inception  2010  Michael (III) August    actor    LAX Passenger   NaN
# 228660   Inception  2010        Virgile Bramly    actor   Bridge Sub Con  29.0
# 331411   Inception  2010         John Ceallach    actor    LAX Passenger   NaN
# 383230   Inception  2010         Nicolas Clerc    actor   Bridge Sub Con  26.0
# 392820   Inception  2010        Adam (IV) Cole    actor      Bar Sub Con  34.0
# 458599   Inception  2010    Jean-Michel Dagory    actor   Bridge Sub Con  30.0
# 654560   Inception  2010      Mark Fleischmann    actor  Penrose Sub Con  32.0
# 738646   Inception  2010         Carl Gilliard    actor    Lobby Sub Con  40.0
# 742450   Inception  2010     Daniel Girondeaud    actor   Bridge Sub Con   NaN
# 894946   Inception  2010       Andrew Hoagland    actor       Pedestrian   NaN
# 1437263  Inception  2010     Jack (III) Murray    actor      Bar Sub Con  35.0
# ...

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
inc = cast[cast.title == 'Inception']
inc[inc.n.isnull()]
# Out:
#              title  year                     name     type  \
# 85565    Inception  2010     Michael (III) August    actor
# 173593   Inception  2010                 Ken Bhan    actor
# 331411   Inception  2010            John Ceallach    actor
# 607103   Inception  2010            Seve Esposito    actor
# 628065   Inception  2010  Zachary Christopher Fay    actor
# 742450   Inception  2010        Daniel Girondeaud    actor
# 894946   Inception  2010          Andrew Hoagland    actor
# 973723   Inception  2010          Charles Jarrell    actor
# 985535   Inception  2010            Seong-hwan Jo    actor
# 995653   Inception  2010          Alonzo F. Jones    actor
# 1056098  Inception  2010               Mobin Khan    actor
# 1149462  Inception  2010         John (IX) Lawson    actor
# 1163695  Inception  2010    Jean-Christophe Leger    actor
# 1478529  Inception  2010     Fran?ois-Marie Nivon    actor
# 1629230  Inception  2010             Scott Pretty    actor
# ...

# %%
len(inc[inc.n.isnull()])
inc[inc.n.isnull()].shape[0]
# Out:
# 21
# 21

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
# inc defined

inc[inc.n.notnull()]
inc[inc.n.notna()]
# Out:
#              title  year                  name     type  \
# 130207   Inception  2010          Peter Basham    actor
# 161273   Inception  2010          Tom Berenger    actor
# 228660   Inception  2010        Virgile Bramly    actor
# 288473   Inception  2010         Michael Caine    actor
# 294438   Inception  2010          Earl Cameron    actor
# 383230   Inception  2010         Nicolas Clerc    actor
# 392820   Inception  2010        Adam (IV) Cole    actor
# 458599   Inception  2010    Jean-Michel Dagory    actor
# 523818   Inception  2010     Leonardo DiCaprio    actor
# 629610   Inception  2010             Russ Fega    actor
# 654560   Inception  2010      Mark Fleischmann    actor
# 717521   Inception  2010        Michael Gaston    actor
# 721274   Inception  2010       Johnathan Geare    actor
# 738646   Inception  2010         Carl Gilliard    actor
# 739830   Inception  2010           Jack Gilroy    actor
# 763310   Inception  2010  Joseph Gordon-Levitt    actor
# ...

# %%
len(inc[inc.n.notnull()])
len(inc[inc.n.notna()])
# Out:
# 51
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
nor = cast[cast.title == 'North by Northwest']

# %%
nor[nor.n.notnull()].sort_values(['n'])
# Out:
#                       title  year                  name     type  \
# 773496   North by Northwest  1959            Cary Grant    actor
# 3084579  North by Northwest  1959       Eva Marie Saint  actress
# 1292652  North by Northwest  1959           James Mason    actor
# 2776446  North by Northwest  1959   Jessie Royce Landis  actress
# 315343   North by Northwest  1959        Leo G. Carroll    actor
# 2685171  North by Northwest  1959  Josephine Hutchinson  actress
# 1504777  North by Northwest  1959           Philip Ober    actor
# 1130557  North by Northwest  1959         Martin Landau    actor
# 2167754  North by Northwest  1959         Adam Williams    actor
# 1607029  North by Northwest  1959          Edward Platt    actor
# 590702   North by Northwest  1959     Robert Ellenstein    actor
# 2033529  North by Northwest  1959          Les Tremayne    actor
# 411247   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
sleuth = castsleuth = cast[(cast.title == 'Sleuth')&(cast.year == 1972)]

# %%
sleuth.sort_values('n')
# Out:
#           title  year                name     type  \
# 1513570  Sleuth  1972    Laurence Olivier    actor
# 288502   Sleuth  1972       Michael Caine    actor
# 330750   Sleuth  1972      Alec Cawthorne    actor
# 1299944  Sleuth  1972  John (II) Matthews    actor
# 2406762  Sleuth  1972  Eve (III) Channing  actress
# 1285278  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1513570                 Andrew Wyke  1.0
# 288502                  Milo Tindle  2.0
# 330750            Inspector Doppler  3.0
# 1299944  Detective Sergeant Tarrant  4.0
# 2406762             Marguerite Wyke  5.0
# 1285278      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
sleuth = cast[(cast.title == 'Sleuth')&(cast.year == 2007)]
sleuth
# Out:
#           title  year                 name     type          character    n
# 228757   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 288503   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 330751   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 1147041  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1602268  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 2406761  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 2958823  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %%
sleuth.sort_values(['n'])
# Out:
#           title  year                 name     type          character    n
# 288503   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1147041  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1602268  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 228757   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 330751   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2406761  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 2958823  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
ham1 = cast[(cast.title == 'Hamlet')&(cast.year == 1921)]
len(ham1)
# Out:
# 9

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
ham2 = cast[(cast.title == 'Hamlet')&(cast.year == 1996)]
len(ham2)
# Out:
# 55

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
ham3 = cast[(cast.title == 'Hamlet')]
len(ham3)
# Out:
# 299

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
oph = cast[cast.character == 'Ophelia']

# %%
len(oph)

len(oph.name.drop_duplicates())
# Out:
# 96
# 94

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
dud = cast[cast.character == 'The Dude']
len(dud)
# Out:
# 16

# %%
len(dud.name.drop_duplicates())
# Out:
# 16

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
stranger = cast[cast.character == 'The Stranger']
len(stranger)
# Out:
# 192

# %%
len(stranger.name.drop_duplicates())
# Out:
# 184

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
sp = cast[cast.name == 'Sidney Poitier']

# %%
len(sp)
sp.character.drop_duplicates().shape

# Answer shall be the first one as he can play 2 roles with the same name
# Out:
# 43
# (41,)

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
jd = cast[cast.name == 'Judi Dench']

# %%
len(jd)
jd.character.drop_duplicates().shape
# Out:
# 51
# (44,)

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
c = cast[(cast.name == 'Cary Grant')&(cast.n == 2)]
c = c[c.year//10 == 194].sort_values('year')
c
# Out:
#                    title  year        name   type    character    n
# 773493  My Favorite Wife  1940  Cary Grant  actor         Nick  2.0
# 773503    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
c = cast[(cast.name == 'Cary Grant')&(cast.n == 1)]
c = c[c.year//10 == 194].sort_values('year')
c
# Out:
#                                        title  year        name   type  \
# 773518               The Howards of Virginia  1940  Cary Grant  actor
# 773475                       His Girl Friday  1940  Cary Grant  actor
# 773520                The Philadelphia Story  1940  Cary Grant  actor
# 773508                             Suspicion  1941  Cary Grant  actor
# 773522                  The Talk of the Town  1942  Cary Grant  actor
# 773499                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 773466                     Destination Tokyo  1943  Cary Grant  actor
# 773491                             Mr. Lucky  1943  Cary Grant  actor
# 773492                             Mr. Lucky  1943  Cary Grant  actor
# 773500                      Once Upon a Time  1944  Cary Grant  actor
# 773458                  Arsenic and Old Lace  1944  Cary Grant  actor
# 773495             None But the Lonely Heart  1944  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
c = cast[cast.year//10 == 195]
c = c[c.type == 'actor']
len(c)
# Out:
# 147951

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
c = cast[cast.year//10 == 195]
c = c[c.type == 'actress']
len(c)
# Out:
# 53969

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
c = cast[(cast.year <= 1980) & (cast.n == 1)]
len(c)
# Out:
# 61444

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
c = cast[(cast.year <= 1980) & (cast.n != 1)]
len(c)
# Out:
# 1047877

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
c = cast[(cast.year <= 1980) & (cast.n.isnull())]
len(c)
# Out:
# 415167
